# %% [markdown]
# <a href="https://colab.research.google.com/github/CoderGauta/Python_Operators/blob/main/python_data_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #datastructure - user define the value more the one
# list
# tuple
# set
# dict

# %%
l = []
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l.append(5)
l
# Out:
# [10, 10, 10, 10, 10, 10, 10, 20, 30, 40, 5]

# %%
l.append(20)
l.append(30)
l.append(40)
l
# Out:
# [10, 10, 10, 10, 10, 10, 10, 20, 30, 40]

# %%
len(l)
# Out:
# 11

# %%
id(l)
# Out:
# 135169347341376

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
a = True
type(a)
# Out:
# bool

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
l[:]
# Out:
# [10, 10, 10, 10, 10, 10, 10, 20, 30, 40, 5]

# %%
l[:-1]
# Out:
# [10, 10, 10, 10, 10, 10, 10, 20, 30, 40]

# %%
l[0]
# Out:
# 10

# %%
l[-2]
# Out:
# 40

# %%
l[-3]
# Out:
# 30

# %%
l[7:-2]
# Out:
# [20, 30]

# %%
l1 = l.copy()
l1
# Out:
# [10, 10, 10, 10, 10, 10, 10, 20, 30, 40, 5]

# %%
l == l1
# Out:
# True

# %%
print(len(l))
print(len(l1))
# Out:
# 11
# 11

# %%
l1
# Out:
# [10, 10, 10, 10, 10, 10, 10, 20, 30, 40, 5]

# %%
l1.append(2.3)
l1.append(True)
l1.append(1+2j)

# %%
l1
# Out:
# [10, 10, 10, 10, 10, 10, 10, 20, 30, 40, 5, 2.3, True, (1+2j)]

# %%
l.count(10)
# Out:
# 7

# %%
l.count(40)
# Out:
# 1

# %%
l.count(100)
# Out:
# 0

# %%
l2 = l1.copy()

# %%
l2
# Out:
# [10, 10, 10, 10, 10, 10, 10, 20, 30, 40, 5, 2.3, True, (1+2j)]

# %%
l2.remove(True)
l2
# Out:
# [10, 10, 10, 10, 10, 10, 10, 20, 30, 40, 5, 2.3, (1+2j)]

# %%
l2.remove(10)
l2
# Out:
# [10, 20, 30, 40, 5, 2.3, (1+2j)]

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2547/2371406284.py in <cell line: 0>()
# ----> 1 l2
#
# NameError: name 'l2' is not defined
