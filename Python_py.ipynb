# %% [markdown]
# <a href="https://colab.research.google.com/github/CoderGauta/Python_Operators/blob/main/Python_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
int(2.3)
# Out:
# 2

# %%
int(2.5)
# Out:
# 2

# %% [markdown]
# type casting

# %%
bool(2)
# Out:
# True

# %%
bool(3.2)
# Out:
# True

# %%
bool(0+0j)
# Out:
# False

# %%
bool("hi")
# Out:
# True

# %%
bool( )
# Out:
# False

# %%
str(3.4)
# Out:
# '3.4'

# %%
str(1+3j)
# Out:
# '(1+3j)'

# %%
str(True)
# Out:
# 'True'

# %% [markdown]
# Type casting is done

# %% [markdown]
# #Python Operator
# -arithmetic operator(+,-,*,/,//,)

# %%
x1, y1 = 15,5

# %%
x1+y1
# Out:
# 20

# %%
x1 - y1
# Out:
# 10

# %%
x1/y1
# Out:
# 3.0

# %%
x1//y1
# Out:
# 3

# %%
x1**y1
# Out:
# 759375

# %%
x1*y1
# Out:
# 75

# %% [markdown]
# #Assignment operator

# %%
x = 2
x
# Out:
# 2

# %%
x = x + 2
x
# Out:
# 8

# %%
x += 2
x
# Out:
# 10

# %%
x += 5
x
# Out:
# 15

# %%
from os import XATTR_SIZE_MAX
x =+ 2
XATTR_SIZE_MAX

# %%
x -= 5
x
# Out:
# 10

# %%
x *= 2
x
# Out:
# 20

# %%
x /= 2
x
# Out:
# 10.0

# %%
x //= 2
x
# Out:
# 5.0

# %%
x // 2
2
# Out:
# 2

# %% [markdown]
# #Unary operator

# %%
n = 7 #negattion
n
# Out:
# 7

# %%
m = -(n)
m
# Out:
# -7

# %%
m
# Out:
# -7

# %% [markdown]
# #relational operators

# %%
r1 = 5
r2 = 6

# %%
r1>r2
# Out:
# False

# %%
r1<r2
# Out:
# True

# %%
r1<=r2
# Out:
# True

# %%
r1>=r2
# Out:
# False

# %%
r1==r2
# Out:
# False

# %%
r1!=r2
# Out:
# True

# %%
r=7

# %%
r3 = 7

# %%
r1>=r3
# Out:
# False

# %%
r1<r3
# Out:
# True

# %% [markdown]
# #Logical Operators
# AND operator
# 1 and 1 = 1
# 1 and 0 = 0
# 0 and 0 = 0
# 0 and 1 = 0
#
# OR operator
# 0 or 0 = 0
# 0 or 1 = 1
# 1 or 0 = 1
# 1 or 1 = 1
#
# NOT operator
# 1 not 1 = 0
# 1 not 0 = 1
# o not 1 = 1
# 0 not 0 = 1

# %%
a = 5
b = 10

# %%
a < 8 and b < 5
# Out:
# False

# %%
a < 8 and b < 12
# Out:
# True

# %%
a > 4 and b > 13
# Out:
# False

# %%
a > 4 and b > 8
# Out:
# True

# %%
a < 8 or b < 12
# Out:
# True

# %%
a > 6 or b > 8
# Out:
# True

# %%
a > 7 or b > 12
# Out:
# False

# %%
a > 6 and b > 8
# Out:
# False

# %%
a > 4 and b > 8
# Out:
# True
